# %%
#   1. What are the five key concepts of Object-Oriented Programming (OOP)?
#  Ans.
#      We have five concepts of OOP are:
#      Encapsulation , Abstraction , Inheritance , Polymorphism , Composition

# %%
# # 2. Write a Python class for a `Car` with attributes for `make`, `model`, and `year`. Include a method to display
# # the car's information.

# Ans.  Python class for a car:-
#     Clear car:
#       def init(self, make, model , year):
#       self.make = make
#       self.model = model
#       self.year = year

# %%
# # 3. Explain the difference between instance methods and class methods. Provide an example of each.
# # Ans. Instance :
# #       It method is a method that is accosiatedwith an instance of a class. It operates on the data (attributes) of a specific instance and can
# #       access instance variables.Instance metohds are called on an object of the class.It always take 'Self' as thier first parameter, which refer
# #       to the particular instance calling the method.

#     class Car:
#         def __init__(self, make, model, year):
#             # Instance attributes
#             self.make = make
#             self.model = model
#             self.year = year
#             self.is_running = False

#         # Instance method to start the car
#         def start(self):
#             self.is_running = True
#             return f"The {self.year} {self.make} {self.model} is now running."

#         # Instance method to stop the car
#         def stop(self):
#             self.is_running = False
#             return f"The {self.year} {self.make} {self.model} has stopped."

#         # Instance method to display car details
#         def display_info(self):
#             return f"Car Info: {self.year} {self.make} {self.model}"

#     # Create an instance of the Car class
#     my_car = Car("Toyota", "Camry", 2020)

#     # Call the instance methods
#     print(my_car.display_info())  # Output: Car Info: 2020 Toyota Camry
#     print(my_car.start())         # Output: The 2020 Toyota Camry is now running.
#     print(my_car.stop())          # Output: The 2020 Toyota Camry has stopped.

#     Class:

#     Class methods are functions that are bound to the class itself rather than its instance. They take the class as their first argument (cls)
#     and can operate on class-level attributes but not instance-level attributes.They are called on the class itself rather than on an instance,
#     and they are defined using the @classmethod decorator.

#         class Car:
#         # Class attribute
#         wheels = 4

#         def __init__(self, make, model, year):
#             # Instance attributes
#             self.make = make
#             self.model = model
#             self.year = year

#         # Class method to access class-level data
#         @classmethod
#         def get_wheels(cls):
#             return f"All cars have {cls.wheels} wheels."

#         # Class method to set the number of wheels (if we want to change it for all cars)
#         @classmethod
#         def set_wheels(cls, num_wheels):
#             cls.wheels = num_wheels

#     # Accessing the class method without creating an instance
#     print(Car.get_wheels())  # Output: All cars have 4 wheels.

#     # Changing the number of wheels for all cars using a class method
#     Car.set_wheels(6)
#     print(Car.get_wheels())  # Output: All cars have 6 wheels.

# %%
# 4. How does Python implement method overloading? Give an example.
# Ans.
#       class Converter:
#           def convert(self, value):
#               # If value is an integer, convert it to a float
#               if isinstance(value, int):
#                   return float(value)

#               # If value is a float, convert it to an integer
#               elif isinstance(value, float):
#                   return int(value)

#               # If value is a string, convert it to uppercase
#               elif isinstance(value, str):
#                   return value.upper()

#               # If no matching type
#               else:
#                   return "Unsupported type"

#       # Create an instance of Converter
#       converter = Converter()

#       # Convert integer to float
#       print(converter.convert(10))  # Output: 10.0

#       # Convert float to integer
#       print(converter.convert(10.5))  # Output: 10

#       # Convert string to uppercase
#       print(converter.convert("hello"))  # Output: HELLO

#       # Handle unsupported type
#       print(converter.convert([1, 2, 3]))  # Output: Unsupported type

#     (B)Using *args for Method Overloading:

#         class Multiplier:
#         def multiply(self, *args):
#             # If no arguments are passed
#             if len(args) == 0:
#                 return "No numbers to multiply"

#             # Initialize result to 1 (multiplicative identity)
#             result = 1

#             # Multiply all arguments together
#             for num in args:
#                 result *= num

#             return result

#     # Create an instance of Multiplier
#     multiplier = Multiplier()

#     # Multiply with no arguments
#     print(multiplier.multiply())  # Output: No numbers to multiply

#     # Multiply with one argument
#     print(multiplier.multiply(5))  # Output: 5

#     # Multiply with two arguments
#     print(multiplier.multiply(5, 3))  # Output: 15

#     # Multiply with three arguments
#     print(multiplier.multiply(2, 3, 4))  # Output: 24

#     (C) Using Default Arguments:

#           class Greet:
#           def say_hello(self, name="Guest", message="Welcome!"):
#               return f"Hello, {name}! {message}"

#       # Create an instance of Greet
#       greeter = Greet()

#       # Call with no arguments (uses both default arguments)
#       print(greeter.say_hello())  # Output: Hello, Guest! Welcome!

#       # Call with one argument (uses default message)
#       print(greeter.say_hello("Alice"))  # Output: Hello, Alice! Welcome!

#       # Call with two arguments (no default used)
#       print(greeter.say_hello("Bob", "Good to see you!"))  # Output: Hello, Bob! Good to see you!

# %%
# 5. What are the three types of access modifiers in Python? How are they denoted?
# Ans. The three types of access modifiers in Python are:
#              Public, Protected, Private
#     (A) Public:

#     Public members are accessible from anywhere, both inside and outside the class.Public members have no special prefix.

#           class Car:
#         def __init__(self, make, model):
#             self.make = make  # Public attribute
#             self.model = model  # Public attribute

#         def display_info(self):  # Public method
#             return f"{self.make} {self.model}"

#         # Usage
#         my_car = Car("Toyota", "Camry")
#         print(my_car.display_info())  # Output: Toyota Camry

#  (B) Protected:
#     Protected members are intended to be accessible within the class and its subclasses. They are not meant to be accessed directly from
#     outside the class.Protected members are prefixed with a single underscore (_).

#             class Car:
#             def __init__(self, make, model):
#                 self._make = make  # Protected attribute
#                 self._model = model  # Protected attribute

#             def _display_info(self):  # Protected method
#                 return f"{self._make} {self._model}"

#         class SportsCar(Car):
#             def show_info(self):
#                 return self._display_info()  # Accessible in subclass

#             # Usage
#             my_sports_car = SportsCar("Ferrari", "488")
#             print(my_sports_car.show_info())  # Output: Ferrari 488
#             # print(my_sports_car._display_info())  # Not recommended to access directly.

#      (c) Private:

#      Private members are intended to be accessible only within the class where they are defined. They are not supposed to be accessed
#      or modified from outside the class.Private members are prefixed with a double underscore (__).

#             class Car:
#           def __init__(self, make, model):
#               self.__make = make  # Private attribute
#               self.__model = model  # Private attribute

#           def __display_info(self):  # Private method
#               return f"{self.__make} {self.__model}"

#           # Usage
#           my_car = Car("Tesla", "Model S")
#           # print(my_car.__make)  # Raises AttributeError: can't access private attribute
#           # print(my_car.__display_info())  # Raises AttributeError: can't access private method

#           # Accessing the private attribute using name mangling
#           print(my_car._Car__make)  # Output: Tesla

# %%
# 6. Describe the five types of inheritance in Python. Provide a simple example of multiple inheritance.
# Ans.
#   1. Single Inheritance:

#       class Vehicle:
#         def start(self):
#             return "Vehicle starting"

#     class Car(Vehicle):
#         def drive(self):
#             return "Car is driving"

#       # Usage
#       my_car = Car()
#       print(my_car.start())  # Output: Vehicle starting
#       print(my_car.drive())  # Output: Car is driving

#   2. Multiple Inheritance:

#       class Engine:
#         def start_engine(self):
#             return "Engine started"

#     class Radio:
#         def play_music(self):
#             return "Playing music"

#     class Car(Engine, Radio):
#         def drive(self):
#             return "Car is driving"

#     # Usage
#     my_car = Car()
#     print(my_car.start_engine())  # Output: Engine started
#     print(my_car.play_music())     # Output: Playing music
#     print(my_car.drive())          # Output: Car is driving

# 3. Multilevel Inheritance:

#         class Vehicle:
#         def start(self):
#             return "Vehicle starting"

#         class Car(Vehicle):
#             def drive(self):
#                 return "Car is driving"

#         class SportsCar(Car):
#             def race(self):
#                 return "Sports car is racing"

#         # Usage
#         my_sports_car = SportsCar()
#         print(my_sports_car.start())  # Output: Vehicle starting
#         print(my_sports_car.drive())   # Output: Car is driving
#         print(my_sports_car.race())    # Output: Sports car is racing

# 4. Hierarchical Inheritance:

#     class Vehicle:
#         def start(self):
#             return "Vehicle starting"

#     class Car(Vehicle):
#         def drive(self):
#             return "Car is driving"

#     class Truck(Vehicle):
#         def haul(self):
#             return "Truck is hauling"

#     # Usage
#     my_car = Car()
#     my_truck = Truck()
#     print(my_car.start())  # Output: Vehicle starting
#     print(my_truck.start())  # Output: Vehicle starting
#     print(my_car.drive())    # Output: Car is driving
#     print(my_truck.haul())    # Output: Truck is hauling

#  5. Hybrid Inheritance:


#   class Vehicle:
#       def start(self):
#           return "Vehicle starting"

#   class Car(Engine, Vehicle):
#       def drive(self):
#           return "Car is driving"

#   class SportsCar(Car):
#       def race(self):
#           return "Sports car is racing"

#   # Usage
#   my_sports_car = SportsCar()
#   print(my_sports_car.start_engine())  # Output: Engine started
#   print(my_sports_car.start())          # Output: Vehicle starting
#   print(my_sports_car.drive())          # Output: Car is driving
#   print(my_sports_car.race())           # Output: Sports car is racing

# %%
# 7. What is the Method Resolution Order (MRO) in Python? How can you retrieve it programmatically?
# Ans.  It is use for when a class inherits from two or more than two class.

#   class X:
#     def show(self):
#         return "Method from class X"

#     class Y(X):
#         def show(self):
#             return "Method from class Y"

#     class Z(X):
#         def show(self):
#             return "Method from class Z"

#     class A(Y, Z):
#         pass

#     # Retrieve MRO
#     print(A.mro())        # Output: [<class '__main__.A'>, <class '__main__.Y'>, <class '__main__.Z'>, <class '__main__.X'>, <class 'object'>]

#     # Alternatively, using __mro__ attribute
#     print(A.__mro__)      # Output: (<class '__main__.A'>, <class '__main__.Y'>, <class '__main__.Z'>, <class '__main__.X'>, <class 'object'>)

#     # Creating an instance of class A
#     a_instance = A()
#     print(a_instance.show())  # Output: Method from class Y

# %%
# # 8. Create an abstract base class `Shape` with an abstract method `area()`. Then create two subclasses
# # `Circle` and `Rectangle` that implement the `area()` method.
# # Ans.
#     # Abstract Base Class
#     class Shape(ABC):
#         #abstractmethod
#         def area(self):
#             pass

#     # Subclass for Circle
#     class Circle(Shape):
#         def __init__(self, radius):
#             self.radius = radius

#         def area(self):
#             return math.pi * (self.radius ** 2)

#     # Subclass for Rectangle
#     class Rectangle(Shape):
#         def __init__(self, width, height):
#             self.width = width
#             self.height = height

#         def area(self):
#             return self.width * self.height

#     # Usage
#     circle = Circle(5)
#     rectangle = Rectangle(4, 6)

#     print(f"Area of Circle: {circle.area():.2f}")      # Output: Area of Circle: 78.54
#     print(f"Area of Rectangle: {rectangle.area()}")    # Output: Area of Rectangle: 24

# %%
# 9. Demonstrate polymorphism by creating a function that can work with different shape objects to calculate
# and print their areas.
# Ans.
#     from abc import ABC, abstractmethod
# import math

# # Abstract Base Class
# class Shape(ABC):
#     abstractmethod
#     def area(self):
#         pass

# # Subclass for Circle
# class Circle(Shape):
#     def __init__(self, radius):
#         self.radius = radius

#     def area(self):
#         return math.pi * (self.radius ** 2)

# # Subclass for Rectangle
# class Rectangle(Shape):
#     def __init__(self, width, height):
#         self.width = width
#         self.height = height

#     def area(self):
#         return self.width * self.height

# # Polymorphic function to calculate and print area
# def print_area(shape: Shape):
#     print(f"The area of the shape is: {shape.area():.2f}")

# # Usage
# circle = Circle(5)
# rectangle = Rectangle(4, 6)

# print_area(circle)      # Output: The area of the shape is: 78.54
# print_area(rectangle)   # Output: The area of the shape is: 24.00

# %%
# 10. Implement encapsulation in a `BankAccount` class with private attributes for `balance` and
# `account_number`. Include methods for deposit, withdrawal, and balance inquiry.

# Ans.
#     class BankAccount:
#     def __init__(self, account_number, initial_balance=0):
#         self.__account_number = account_number  # Private attribute
#         self.__balance = initial_balance          # Private attribute

#     def deposit(self, amount):
#         if amount > 0:
#             self.__balance += amount
#             print(f"Deposited: ${amount:.2f}")
#         else:
#             print("Deposit amount must be positive.")

#     def withdraw(self, amount):
#         if 0 < amount <= self.__balance:
#             self.__balance -= amount
#             print(f"Withdrew: ${amount:.2f}")
#         else:
#             print("Insufficient funds or invalid amount.")

#     def get_balance(self):
#         return self.__balance

#     def get_account_number(self):
#         return self.__account_number

# # Usage
# account = BankAccount("12345678", 1000)

# # Deposit money
# account.deposit(500)              # Output: Deposited: $500.00

# # Withdraw money
# account.withdraw(200)             # Output: Withdrew: $200.00

# # Check balance
# print(f"Current Balance: ${account.get_balance():.2f}")  # Output: Current Balance: $1300.00

# # Attempt to withdraw more than balance
# account.withdraw(1500)            # Output: Insufficient funds or invalid amount.

# %%
# # 11. Write a class that overrides the `__str__` and `__add__` magic methods. What will these methods allow
# # you to do?

# # Ans.Arguments class that overrides the __str__ and __add__ magic methods. This will allow you to customize the string representation of the class and
# #  define how objects of the class can be added together.
#       class Car:
#         def __init__(self, make, model, year):
#             self.make = make
#             self.model = model
#             self.year = year

#         # Overriding __str__ for a custom string representation
#         def __str__(self):
#             return f"{self.year} {self.make} {self.model}"

#         # Overriding __add__ to combine two Car objects
#         def __add__(self, other):
#             if isinstance(other, Car):
#                 combined_year = (self.year + other.year) // 2  # Average year for demonstration
#                 return Car(self.make, self.model, combined_year)
#             return NotImplemented

#       # Usage
#       car1 = Car("Toyota", "Camry", 2020)
#       car2 = Car("Honda", "Accord", 2022)

#       # String representation
#       print(car1)  # Output: 2020 Toyota Camry
#       print(car2)  # Output: 2022 Honda Accord

#       # Adding two Car objects
#       car3 = car1 + car2
#       print(car3)  # Output: 2021 Toyota Camry (averaging years)

# %%
# 12. Create a decorator that measures and prints the execution time of a function.
# Ans.

# import time

# # Timing decorator
# def timing_decorator(func):
#     def wrapper(*args, **kwargs):
#         start_time = time.time()  # Record the start time
#         result = func(*args, **kwargs)  # Call the original method
#         end_time = time.time()  # Record the end time
#         execution_time = end_time - start_time  # Calculate the execution time
#         print(f"Execution time for {func.__name__}: {execution_time:.4f} seconds")
#         return result  # Return the result of the original method
#     return wrapper

# # Car class with a method to simulate a long operation
# class Car:
#     def __init__(self, make, model):
#         self.make = make
#         self.model = model

#     @timing_decorator
#     def start_engine(self):
#         print(f"{self.make} {self.model}: Starting engine...")
#         time.sleep(2)  # Simulate a time-consuming operation
#         print(f"{self.make} {self.model}: Engine started.")

#     @timing_decorator
#     def drive(self):
#         print(f"{self.make} {self.model}: Driving...")
#         time.sleep(3)  # Simulate a longer time-consuming operation
#         print(f"{self.make} {self.model}: Stopped driving.")

# # Usage
# car1 = Car("Toyota", "Camry")
# car1.start_engine()  # This will print the execution time
# car1.drive()         # This will print the execution time

# %%
# 13. Explain the concept of the Diamond Problem in multiple inheritance. How does Python resolve it?
# Ans. The Diamond Problem occurs in object-oriented programming when a class inherits from two classes that both inherit from a common base class.
#    This creates an ambiguity about which method or property to inherit when multiple paths lead back to the same base class.

#    class A:
#     def greet(self):
#         return "Hello from A"

#   class B(A):
#       def greet(self):
#           return "Hello from B"

#   class C(A):
#       def greet(self):
#           return "Hello from C"

#   class D(B, C):
#       pass

#   # Usage
#   d_instance = D()
#   print(d_instance.greet())          # Output: Hello from B
#   print(D.mro())                     # Output: [<class '__main__.D'>, <class '__main__.B'>, <class '__main__.C'>, <class '__main__.A'>, <class 'object'>]

# %%
# 14. Write a class method that keeps track of the number of instances created from a class.
# Ans. A class method in Python that keeps track of the number of instances created from a class.

#   class Car:
#     instance_count = 0  # Class variable to keep track of the number of instances

#     def __init__(self, make, model):
#         self.make = make
#         self.model = model
#         Car.instance_count += 1  # Increment the instance count whenever a new instance is created

#     @classmethod
#     def get_instance_count(cls):
#         return cls.instance_count  # Return the current instance count

#     # Usage
#     car1 = Car("Toyota", "Camry")
#     car2 = Car("Honda", "Accord")
#     car3 = Car("Ford", "Mustang")

#     # Get the number of instances created
#     print(f"Number of Car instances created: {Car.get_instance_count()}")  # Output: Number of Car instances created: 3

# %%
# 15. Implement a static method in a class that checks if a given year is a leap year.
# Ans.

#     class YearUtils:
#         @staticmethod
#         def is_leap_year(year):
#             """Check if the given year is a leap year."""
#             if (year % 4 == 0 and year % 100 != 0) or (year % 400 == 0):
#                 return True
#             return False

#     # Usage
#     year = 2024
#     if YearUtils.is_leap_year(year):
#         print(f"{year} is a leap year.")  # Output: 2024 is a leap year.
#     else:
#         print(f"{year} is not a leap year.")

#     year = 1900
#     if YearUtils.is_leap_year(year):
#         print(f"{year} is a leap year.")
#     else:
#         print(f"{year} is not a leap year.")  # Output: 1900 is not a leap year.
